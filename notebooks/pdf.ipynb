# %%
import sys
sys.path.append("..")

from app.services.pdf import PageRendererService

# %%
renderer = PageRendererService()

# %%
pages_paths = renderer.render_pages(
    pdf_path="../data/raw/HYST Smart phone quotation 5-11.pdf",
    output_dir="../data/pages/",
)
# Out:
# MuPDF error: format error: No common ancestor in structure tree
#
# MuPDF error: format error: No common ancestor in structure tree
#
# MuPDF error: format error: No common ancestor in structure tree
#
# MuPDF error: format error: No common ancestor in structure tree
#
# MuPDF error: format error: No common ancestor in structure tree
#
# MuPDF error: format error: No common ancestor in structure tree
#
# MuPDF error: format error: No common ancestor in structure tree
#
# MuPDF error: format error: No common ancestor in structure tree
